# %%
import pandas as pd

# Load the entire workbook into a dictionary of dataframes
data = pd.read_excel('./import/Core_Merch_RICE_Tracker.xlsx', sheet_name=None)

# Access a specific sheet by its name
data['CM-RICE List']
# Out:
# /Users/u1002018/Library/Python/3.9/lib/python/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/u1002018/Library/Python/3.9/lib/python/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                X                                        2  \
# 0            NaN                                      NaN
# 1        RICE ID                                RICE Name
# 2    MRC-CNV-201  Codes and Descriptions (Initial Config)
# 3    MRC-CNV-202            Merchandising system options
# 4    MRC-CNV-203     Custom Flex Attributes Configuration
# ..           ...                                      ...
# 437  MRC-INT-344               Expense Invoice to Vendors
# 438  MRC-INT-346           Price Approval Workflow Report
# 439  MRC-INT-XXX                  Placeholder Integration
# ...

# %%
data['CM-RICE List'].rename(columns=data['CM-RICE List'].iloc[1])
# Out:
#          RICE ID                                RICE Name  \
# 0            NaN                                      NaN
# 1        RICE ID                                RICE Name
# 2    MRC-CNV-201  Codes and Descriptions (Initial Config)
# 3    MRC-CNV-202            Merchandising system options
# 4    MRC-CNV-203     Custom Flex Attributes Configuration
# ..           ...                                      ...
# 437  MRC-INT-344               Expense Invoice to Vendors
# 438  MRC-INT-346           Price Approval Workflow Report
# 439  MRC-INT-XXX                  Placeholder Integration
# 440  MRC-INT-XXX                  Placeholder Integration
# 441   MRC-INT-XX                  Placeholder Integration
#
#                         Deployment Group  In Scope  Object Type  \
# 0                                    NaN       NaN          NaN
# 1                       Deployment Group  In Scope  Object Type
# 2    Retail: R1 - Global foundation, PCS         Y   Conversion
# ...
